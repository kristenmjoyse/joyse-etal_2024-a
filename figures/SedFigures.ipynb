# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_excel("Data2.xlsx", sheet_name = 'Sheet1')
# data2 = pd.read_excel("Data2.xlsx", sheet_name = 'Sheet2')
data2 = pd.read_excel("ClaySiltSand.xlsx")
data3 = pd.read_excel("geochem.xlsx", sheet_name = 'Sheet1')

data2.head()
# Out:
#    Depth (cm)       Clay       Silt  Clay and Silt       Sand    All
# 0         1.5  21.451982  59.593364      81.045345  18.954655  100.0
# 1         2.5  10.393199  38.140770      48.533969  51.466031  100.0
# 2         4.5   0.650065   4.674389       5.324454  94.675546  100.0
# 3         5.5   0.750000   4.252939       5.002939  94.997061  100.0
# 4         6.5   7.635000  31.045461      38.680460  61.319540  100.0

# %%
fig = plt.figure(figsize = (8,10))

loi = fig.add_subplot(141)
d50 = fig.add_subplot(142)
d90 = fig.add_subplot(143)
d10 = fig.add_subplot(144)


### LOI ###

data.plot(kind = 'line', x = 'LOI (%)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = loi, legend = None)

loi.invert_yaxis()
loi.set_ylim(125,0)
loi.set_ylabel('Depth (cm)')

### d50 ###

data.plot(kind = 'line', x = 'D50', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = d50, legend = None)

d50.invert_yaxis()
d50.set_ylim(125,0)
d50.invert_xaxis()
d50.set_yticks([])

### d90 ###

data.plot(kind = 'line', x = 'D90', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = d90, legend = None)

d90.invert_yaxis()
d90.set_ylim(125,0)
d90.invert_xaxis()
d90.set_yticks([])

### d10 ###

data.plot(kind = 'line', x = 'D10', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = d10, legend = None)

d10.invert_yaxis()
d10.set_ylim(125,0)
d10.invert_xaxis()
d10.set_yticks([])

plt.savefig("SedData", bbox_inches = 'tight')

# %%
fig = plt.figure(figsize = (15,10))

loi = fig.add_subplot(151)
mgs = fig.add_subplot(152)
gs = mgs.twiny()
# d90 = fig.add_subplot(143)
# d10 = fig.add_subplot(144)
d13C = fig.add_subplot(153)
CN = fig.add_subplot(154)
d15N = fig.add_subplot(155)


data.plot(kind = 'line', x = 'LOI (%)', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = loi, legend = None)
# data.plot(kind = 'scatter', x = 'zeros', y = 'Plotting Depth (cm)', ax = loi, marker = '<', color = 'black')

loi.invert_yaxis()
loi.set_ylim(125,0)
loi.set_ylabel('Depth (cm)', fontsize = 14)
loi.tick_params(axis='x', labelsize=12)
loi.tick_params(axis='y', labelsize=12)
loi.set_xlabel('LOI (%)', fontsize = 14)
loi.set_xlim(-5, 40)

data2.plot(kind = 'line', x = 'Clay', y = 'Depth (cm)', color = 'lightgray', linewidth = 1, ax = gs, legend = None)
data2.plot(kind = 'line', x = 'Clay and Silt', y = 'Depth (cm)', color = 'darkgray', linewidth = 1, ax = gs, legend = None)

data.plot(kind = 'line', x = 'Mean Grain Size', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = mgs, legend = None)

gs.invert_yaxis()
gs.set_ylim(125,0)
gs.tick_params(axis='x', labelsize=12)
mgs.tick_params(axis='x', labelsize=12)
gs.set_xlabel('Cumulative Volume by Grain Size (%)', fontsize = 14)
mgs.set_xlim(2,7)
mgs.invert_xaxis()
mgs.set_xlabel('Mean Grain Size ($\phi$)', fontsize = 14)
gs.set_xlim(0, 100)
mgs.set_yticklabels([])

# data.plot(kind = 'line', x = 'D90', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = d90, legend = None)

# d90.invert_yaxis()
# d90.set_ylim(125,0)
# d90.invert_xaxis()
# d90.set_yticklabels([])
# d90.set_xlim(10.5,3)
# d90.tick_params(axis='x', labelsize=12)
# d90.set_xlabel('d90 ($\phi$)', fontsize = 14)

# data.plot(kind = 'line', x = 'D10', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = d10, legend = None)

# d10.invert_yaxis()
# d10.set_ylim(125,0)
# d10.invert_xaxis()
# d10.set_yticklabels([])
# d10.set_xlim(4,1)
# d10.tick_params(axis='x', labelsize=12)
# d10.set_xlabel('d10 ($\phi$)', fontsize = 14)

data3.plot(kind = 'line', x = 'd13C', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = d13C, legend = None)

d13C.invert_yaxis()
# d13C.invert_xaxis()
d13C.set_ylim(125,0)
d13C.set_xlim(-35, -15)
d13C.set_yticklabels([])
# d13C.set_ylabel('Depth (cm)', fontsize = 14)
d13C.set_xlabel('Organic \u03B413C (\u2030)', fontsize = 14)
d13C.tick_params(axis = 'x', labelsize = 12)
d13C.tick_params(axis = 'y', labelsize = 12)
# d13C.set_xticklabels(d13C.get_xticks(), font = fpath)
# d13C.set_yticklabels(d13C.get_yticks(), font = fpath)

data3.plot(kind = 'line', x = 'C/N', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = CN, legend = None)

CN.invert_yaxis()
CN.set_ylim(125,0)
CN.set_xlim(0,20)
CN.set_yticklabels([])
CN.set_xlabel('C/N', fontsize = 14)
CN.tick_params(axis = 'x', labelsize = 12)
# CN.set_xticklabels(CN.get_xticks(), font = fpath)

data3.plot(kind = 'line', x = 'd15N', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = d15N, legend = None)

d15N.invert_yaxis()
d15N.set_ylim(125,0)
d15N.set_xlim(-3,9)
d15N.set_yticklabels([])
d15N.set_xlabel('\u03B415N (\u2030)', fontsize = 14)
d15N.tick_params(axis = 'x', labelsize = 12)
# d15N.set_xticklabels(d15N.get_xticks(), font = fpath)

plt.savefig("SedFig_v3.pdf", dpi = 500, bbox_inches = 'tight')

# %%
fig = plt.figure(figsize = (8,10))

mgs1 = fig.add_subplot(121)
mgs2 = fig.add_subplot(122)

data.plot(kind = 'line', x = 'Mean Grain Size', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = mgs1, legend = None)

mgs1.invert_yaxis()
mgs1.set_ylim(130,0)
mgs1.tick_params(axis='x', labelsize=12)
mgs1.set_xlim(2,8)
mgs1.invert_xaxis()
mgs1.set_xlabel('Mean Grain Size ($\phi$)', fontsize = 14)
mgs1.set_ylabel('Depth (cm)', fontsize = 14)

data2.plot(kind = 'line', x = 'Mean Grain Size', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = mgs2, legend = None)

mgs2.invert_yaxis()
mgs2.set_ylim(130,-2)
mgs2.set_yticklabels([])
mgs2.tick_params(axis='x', labelsize=12)
mgs2.set_xlim(2,8)
mgs2.invert_xaxis()
mgs2.set_xlabel('Mean Grain Size ($\phi$)', fontsize = 14)

plt.savefig("GrainSizeCompare.pdf", dpi = 500, bbox_inches = 'tight')

# %%
chrono_data = pd.read_excel("ChronoData.xlsx", sheet_name = "RawData")
cs_data = pd.read_excel("ChronoData.xlsx", sheet_name = "Cs137")

chrono_data.head()
# Out:
#    Plotting Depth (cm)    Ni (ppb)    Cu (ppb)    Zn (ppb)  Cd (ppb)  \
# 0                  3.5   22.150550   83.795272  136.710024  0.468538
# 1                  7.5   38.339927  201.046492  194.424799  0.564037
# 2                 11.5   51.482571  218.583818  327.137862  0.867161
# 3                 15.5  111.278079  433.900437  870.719586  2.903819
# 4                 19.5   37.744576  125.246266  239.865269  0.684011
#
#       Pb (ppb)  206Pb:207Pb  Cs137
# 0   331.535978     1.174822    NaN
# 1   246.736601     1.174165    NaN
# 2   960.775849     1.182870    NaN
# 3  1058.143935     1.177863    NaN
# 4   238.195997     1.192852    NaN

# %%
fig = plt.figure(figsize = (12,10))

zn = fig.add_subplot(161)
cd = fig.add_subplot(162)
cu = fig.add_subplot(163)
ni = fig.add_subplot(164)
pb = fig.add_subplot(165)
pbpb = fig.add_subplot(166)

### Zn ###

chrono_data.plot(kind = 'line', x = 'Zn (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = zn, legend = None)

zn.invert_yaxis()
zn.set_ylim(100,0)
zn.set_ylabel('Depth (cm)')

### Cd ###

chrono_data.plot(kind = 'line', x = 'Cd (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cd, legend = None)

cd.invert_yaxis()
cd.set_ylim(100,0)
cd.set_yticks([])

### Cu ###

chrono_data.plot(kind = 'line', x = 'Cu (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cu, legend = None)

cu.invert_yaxis()
cu.set_ylim(100,0)
cu.set_yticks([])

### Ni ###

chrono_data.plot(kind = 'line', x = 'Ni (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = ni, legend = None)

ni.invert_yaxis()
ni.set_ylim(100,0)
ni.set_yticks([])

### Pb ###

chrono_data.plot(kind = 'line', x = 'Pb (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = pb, legend = None)

pb.invert_yaxis()
pb.set_ylim(100,0)
pb.set_yticks([])

### Pb ###

chrono_data.plot(kind = 'line', x = '206Pb:207Pb', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = pbpb, legend = None)

pbpb.invert_yaxis()
pbpb.set_ylim(100,0)
pbpb.set_yticks([])

plt.savefig("HeavyMetals", bbox_inches = 'tight')

# %%
chrono_data = pd.read_excel("ChronoData.xlsx", sheet_name = "NormxLOI")
pollen_data = pd.read_excel("ChronoData.xlsx", sheet_name = "Pollen")

chrono_data.head()
# Out:
#    Plotting Depth (cm)  Ni (ppb)   Cu (ppb)   Zn (ppb)  Cd (ppb)   Pb (ppb)  \
# 0                  3.5  2.215055   8.379527  13.671002  0.046854  33.153598
# 1                  7.5  1.916996  10.052325   9.721240  0.028202  12.336830
# 2                 11.5  1.560078   6.623752   9.913269  0.026278  29.114420
# 3                 15.5  8.902246  34.712035  69.657567  0.232306  84.651515
# 4                 19.5  7.548915  25.049253  47.973054  0.136802  47.639199
#
#    206Pb:207Pb
# 0     0.117482
# 1     0.058708
# 2     0.035845
# 3     0.094229
# 4     0.238570

# %%
fig = plt.figure(figsize = (10,10))

# zn = fig.add_subplot(181)
# cd = fig.add_subplot(182)
# cu = fig.add_subplot(183)
# ni = fig.add_subplot(184)
pb = fig.add_subplot(151)
pbpb = fig.add_subplot(152)
amb = fig.add_subplot(153)
aq = fig.add_subplot(154)
cs = fig.add_subplot(155)

### Zn ###

# chrono_data.plot(kind = 'line', x = 'Zn (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = zn, legend = None)

# zn.invert_yaxis()
# zn.set_ylim(100,0)
# zn.set_ylabel('Depth (cm)', fontsize = 14)
# zn.set_xlabel('Zn (ppb)', fontsize = 14)

### Cd ###

# chrono_data.plot(kind = 'line', x = 'Cd (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cd, legend = None)

# cd.invert_yaxis()
# cd.set_ylim(100,0)
# cd.set_yticks([])
# cd.set_xlabel('Cd (ppb)', fontsize = 14)

### Cu ###

# chrono_data.plot(kind = 'line', x = 'Cu (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cu, legend = None)

# cu.invert_yaxis()
# cu.set_ylim(100,0)
# cu.set_yticks([])
# cu.set_xlabel('Cu (ppb)', fontsize = 14)

### Ni ###

# chrono_data.plot(kind = 'line', x = 'Ni (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = ni, legend = None)

# ni.invert_yaxis()
# ni.set_ylim(100,0)
# ni.set_yticks([])
# ni.set_xlabel('Ni (ppb)', fontsize = 14)

### Pb ###

chrono_data.plot(kind = 'line', x = 'Pb (ppb)', y = 'Plotting Depth (cm)', color = 'black', marker = 'o', markerfacecolor = 'white', linewidth = 1, ax = pb, legend = None)

pb.invert_yaxis()
pb.set_ylim(100,0)
# pb.set_yticks([])
pb.set_xlabel('Pb (ppb)', fontsize = 13)
pb.set_ylabel('Depth (cm)', fontsize = 14)

### Pb ###

chrono_data.plot(kind = 'line', x = '206Pb:207Pb', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = pbpb, legend = None)

pbpb.invert_yaxis()
pbpb.set_ylim(100,0)
pbpb.set_yticks([])
pbpb.set_xlabel('206Pb:207Pb', fontsize = 13)

### Ambrosia ###

pollen_data.plot(kind = 'line', x = 'Ambrosia', y = 'Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = amb, legend = None)

amb.invert_yaxis()
amb.set_ylim(100,0)
amb.set_yticks([])
amb.set_xlabel('$\it{Ambrosia}$ \n Abundance (%)', fontsize = 13)

### Quercus:Ambrosia ###

pollen_data.plot(kind = 'line', x = 'QuercusAmbrosia', y = 'Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = aq, legend = None)

aq.invert_yaxis()
aq.set_ylim(100, 0)
aq.set_yticks([])
aq.set_xlabel('$\it{Quercus:Ambrosia}$', fontsize = 13)

### Cs-137 ###

cs_data.plot(kind = 'line', x = 'Cs137', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cs, legend = None)

cs.invert_yaxis()
cs.set_ylim(100,0)
cs.set_yticks([])
cs.set_xlabel('Cs-137 \n Activity (dpm/g)', fontsize = 13)

plt.savefig("HeavyMetals_NormxLOI.pdf", dpi = 300, bbox_inches = 'tight')

# %%
chrono_data = pd.read_excel("ChronoData.xlsx", sheet_name = "Normxd50")

chrono_data.head()
# Out:
#    Plotting Depth (cm)   Ni (ppb)   Cu (ppb)    Zn (ppb)  Cd (ppb)  \
# 0                  3.5   7.383517  27.931757   45.570008  0.156179
# 1                  7.5   9.584982  50.261623   48.606200  0.141009
# 2                 11.5   7.683966  32.624450   48.826547  0.129427
# 3                 15.5  17.172543  66.959944  134.370306  0.448120
# 4                 19.5   6.989736  23.193753   44.419494  0.126669
#
#      Pb (ppb)  206Pb:207Pb
# 0  110.511993     0.391607
# 1   61.684150     0.293541
# 2  143.399380     0.176548
# 3  163.293817     0.181769
# 4   44.110370     0.220899

# %%
fig = plt.figure(figsize = (12,10))

zn = fig.add_subplot(161)
cd = fig.add_subplot(162)
cu = fig.add_subplot(163)
ni = fig.add_subplot(164)
pb = fig.add_subplot(165)
pbpb = fig.add_subplot(166)

### Zn ###

chrono_data.plot(kind = 'line', x = 'Zn (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = zn, legend = None)

zn.invert_yaxis()
zn.set_ylim(100,0)
zn.set_ylabel('Depth (cm)')

### Cd ###

chrono_data.plot(kind = 'line', x = 'Cd (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cd, legend = None)

cd.invert_yaxis()
cd.set_ylim(100,0)
cd.set_yticks([])

### Cu ###

chrono_data.plot(kind = 'line', x = 'Cu (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = cu, legend = None)

cu.invert_yaxis()
cu.set_ylim(100,0)
cu.set_yticks([])

### Ni ###

chrono_data.plot(kind = 'line', x = 'Ni (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = ni, legend = None)

ni.invert_yaxis()
ni.set_ylim(100,0)
ni.set_yticks([])

### Pb ###

chrono_data.plot(kind = 'line', x = 'Pb (ppb)', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = pb, legend = None)

pb.invert_yaxis()
pb.set_ylim(100,0)
pb.set_yticks([])

### Pb ###

chrono_data.plot(kind = 'line', x = '206Pb:207Pb', y = 'Plotting Depth (cm)', color = 'black', linewidth = 1, marker = 'o', markerfacecolor = 'white', ax = pbpb, legend = None)

pbpb.invert_yaxis()
pbpb.set_ylim(100,0)
pbpb.set_yticks([])

plt.savefig("HeavyMetals_Normxd50", bbox_inches = 'tight')
